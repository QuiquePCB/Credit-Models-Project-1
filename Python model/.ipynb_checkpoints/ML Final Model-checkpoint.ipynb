# %% [markdown]
# # PERSONAL LOAN CREDIT SCORING MODEL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

from catboost import CatBoostClassifier, Pool
from xgboost import XGBClassifier, XGBRegressor
from sklearn.ensemble import StackingClassifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Functions

# %%
"""
Function to load the data for training and validating the model.
The information will not be provided by the end user but will instead be pre-established. The cleaned and structured data file from the repository will be used.
"""
def get_data(data):
    return pd.read_csv(data)

# %%
"""
Function to split the data into training and testing sets.
70% of the total data will be used to train the model, and the remaining 30% will be used to evaluate its performance.
The data split will be performed randomly, with a fixed seed set to ensure reproducibility of the results.
This function  takes the data obtained from the previous function and the target column to predict.
"""
def split_train_test(data, target_column, random_state=100):
    data_train, data_test = train_test_split(
        data,
        test_size=0.3,
        random_state=random_state,
        stratify=data[target_column]  
    )
    return data_train.reset_index(drop=True), data_test.reset_index(drop=True)

# %%
"""
Data preprocessing function
Since the models to be used later require the data to be separated into X and Y, in addition to being normalized 
(only numerical values), it was decided to create a function to perform this preparation.
To use it, you must feed this function with the selected train and test data obtained in the previous function.
"""

def prepare_variables(data_train, data_test):
    X_train = data_train.drop('Credit_Score', axis=1)
    y_train = data_train['Credit_Score']
    X_test = data_test.drop('Credit_Score', axis=1)
    y_test = data_test['Credit_Score']

    numeric_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = X_train.select_dtypes(exclude=['int64', 'float64']).columns

    scaler = StandardScaler()
    X_train_scaled = X_train.copy()
    X_test_scaled = X_test.copy()
    
    X_train_scaled[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
    X_test_scaled[numeric_cols] = scaler.transform(X_test[numeric_cols])

    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
"""
Function for categorical variables
A function was created that takes the separated train and test data and converts categorical variables into dummy 
variables or assigns them a numerical value. This function will be useful since several models to be tested cannot
work with categorical variables.
"""
def preprocess_data(X_train, X_test, y_train, y_test):
    X_train_processed = X_train.copy()
    X_test_processed = X_test.copy()
    
    X_train_processed = pd.get_dummies(X_train_processed, 
                                     columns=['Payment_of_Min_Amount'], 
                                     drop_first=True)
    
    X_test_processed = pd.get_dummies(X_test_processed, 
                                    columns=['Payment_of_Min_Amount'], 
                                    drop_first=True)
    
    X_train_processed = pd.get_dummies(X_train_processed, 
                                     columns=['Payment_Behaviour'], 
                                     drop_first=True)
    
    X_test_processed = pd.get_dummies(X_test_processed, 
                                    columns=['Payment_Behaviour'], 
                                    drop_first=True)
    
    missing_cols = set(X_train_processed.columns) - set(X_test_processed.columns)
    for col in missing_cols:
        X_test_processed[col] = 0
    X_test_processed = X_test_processed[X_train_processed.columns]
    
    ordinal_mapping = {'Poor': 0, 'Standard': 1, 'Good': 2}
    ordinal_mapping2 = {'Bad': 0, 'Standard': 1, 'Good': 2}
    X_train_processed['Credit_Mix'] = X_train_processed['Credit_Mix'].map(ordinal_mapping2)
    X_test_processed['Credit_Mix'] = X_test_processed['Credit_Mix'].map(ordinal_mapping2)
    
    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_test_encoded = le.transform(y_test)
    
    return X_train_processed, X_test_processed, y_train_encoded, y_test_encoded

# %%
"""
Logistic Regression Function
This model will serve to establish a benchmark.
"""
def logistic_regression(X_train, y_train, X_test):
    lr_model = LogisticRegression(max_iter=1000, random_state=100)
    lr_model.fit(X_train, y_train)
    lr_probs = lr_model.predict_proba(X_test)[:, 1]
    lr_preds = lr_model.predict(X_test)
    
    return lr_probs,lr_preds, lr_model

# %%
"""
Function to create an initial model using the Random Forest method.
This function will process the normalized data to generate both a prediction and its associated probability.
The input parameters will be the data for X, excluding categorical variables, so that the data have the fewest 
transformations.The only transformation mentioned will be for column Y, since it cannot be eliminated as it is the
variable to be predicted. However, this model cannot work with non-numeric variables.
"""
def random_forest(X_train, X_test, y_train, params:dict):
    rf_model = RandomForestClassifier(random_state=100, **params)
    rf_model.fit(X_train, y_train)
    rf_probs = rf_model.predict_proba(X_test)[:, 1]
    rf_preds = rf_model.predict(X_test)
    
    return rf_probs,rf_preds, rf_model

# %%
"""
Function to create a catboost model
This model is very useful for categorical variables.For this function, the data will be used without preprocessing, 
since the categorical variables need to be present.
"""
def catboost_model(X_train, y_train, X_test=None, return_proba=True, **params):
    
    cat_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
    
    train_pool = Pool(
        data=X_train,
        label=y_train,
        cat_features=cat_features
    )
    
    model = CatBoostClassifier(
        **params
    )
    
    model.fit(train_pool)

    test_pool = Pool(
        data=X_test,
        cat_features=cat_features
    )
    if return_proba:
        probs = model.predict_proba(test_pool)[:, 1]
    else:
        probs = None
        
    preds = model.predict(test_pool)
    return probs, preds, model

# %%
"""
Function to create a xgboost model
This model is very useful for numerical variables.

"""
def xgboost_model(X_train,X_test,y_train, task_type='classification', **params):
   
    if task_type == 'classification':
        model = XGBClassifier(**params)
    else:
        model = XGBRegressor(**params)
        
    model.fit(X_train, y_train)
    xgrobs = model.predict_proba(X_test)[:, 1]
    xgreds = model.predict(X_test)
    
    return xgrobs,xgreds, model

# %%
"""
Function to get the ROC metrics
"""
def get_roc_metrics(y_test, y_prob, classes):
    y_test_bin = label_binarize(y_test, classes=classes)

    roc_metrics = []
    for i, class_label in enumerate(classes):
        fpr, tpr, treshold = roc_curve(y_test_bin[:, i], y_prob[:, i])
        auc_score = auc(fpr, tpr)
        roc_metrics.append((class_label, fpr, tpr, auc_score, treshold))

    return roc_metrics

# %%
"""
Function that validates a CSV file, adds missing columns, and fills empty values.

"""
def validate_and_clean_csv(csv_file, fill_value=0):
    required_columns = [
    "Age",
    "Annual_Income",
    "Monthly_Inhand_Salary",
    "Num_Bank_Accounts",
    "Num_Credit_Card",
    "Interest_Rate",
    "Num_of_Loan",
    "Mortgage Loan",
    "Not Specified",
    "Personal Loan",
    "Debt Consolidation Loan",
    "Credit-Builder Loan",
    "Payday Loan",
    "Home Equity Loan",
    "Auto Loan",
    "Student Loan",
    "Delay_from_due_date",
    "Num_of_Delayed_Payment",
    "Changed_Credit_Limit",
    "Num_Credit_Inquiries",
    "Credit_Mix",
    "Outstanding_Debt",
    "Credit_Utilization_Ratio",
    "Credit_History_Age",
    "Payment_of_Min_Amount",
    "Total_EMI_per_month",
    "Amount_invested_monthly",
    "Payment_Behaviour",
    "Monthly_Balance"
]
    
    df = pd.read_csv(csv_file)

    # Check for required columns
    missing_columns = [col for col in required_columns if col not in df.columns]

    # Add missing columns filled with zeros
    for col in missing_columns:
        df[col] = fill_value

    # Fill empty values in all columns with specified value
    df.fillna(fill_value, inplace=True)

    # Ensure columns are in the correct order
    df = df[required_columns]
    
    return df

# %%
"""
Function to evaluate a dataset with the final model

"""

def get_predictions(file):
    data = validate_and_clean_csv(file, fill_value=0)
    prediction = stacked_model.predict(data)
    return prediction

# %% [markdown]
# ## Data Pre-Processing

# %%
data_path = "data_all_num_bank_cleaned_expanded.csv" # Path to our dataset
data = get_data(data_path) # Load the dataset

# %%
# Fill categorical nans using mode
categorical_columns = ['Payment_of_Min_Amount', 'Credit_Mix', "Payment_Behaviour"]
for col in categorical_columns:
    data[col] = data[col].fillna(data[col].mode()[0]) 

# Fill numerical nans with 0  
data.fillna(0, inplace=True)

# %%
# Split between train and test data
data_train, data_test = split_train_test(data,target_column="Credit_Score", random_state=100)

# %%
# Prepare the data for training and testing, scaling numerical variables, leave categorical ones as is (for CatBoost)
X_train_scaled,X_test_scaled, y_train, y_test= prepare_variables(data_train,data_test)

# %%
# Prepare the data for training and testing, scaling numerical variables and encoding categorical ones
X_train_processed, X_test_processed, y_train_encoded, y_test_encoded= preprocess_data(X_train_scaled, X_test_scaled, y_train, y_test)

# %% [markdown]
# ## Modelos Base

# %% [markdown]
# ### Benchmark (Logistic Regression)

# %%
# Logistic regression model for benchamarking
num_cols = X_train_scaled.select_dtypes(include=['int64', 'float64']).columns
X_train_b = X_train_scaled[num_cols]
X_test_b = X_test_scaled[num_cols]
    
probs, preds, model_lg = logistic_regression(
    X_train_b, 
    y_train_encoded, 
    X_test_b
)

accuracy_benchmark = accuracy_score(y_test_encoded, preds)
accuracy_benchmark
# Out:
# 0.6385572679256204

# %% [markdown]
# ### XG Boost

# %%
# XGBOOST MODEL
# Declare parameters for extreme gradient boosting model
xgb_params = {
    "booster": "gbtree",
    "objective": 'multi:softprob',
    'learning_rate': 0.01,
    'n_estimators': 800,
    'random_state': 42,

    'max_depth': 20,
    "gamma": 0.7, # Information gain neccesary to split a node
    "subsample": 0.8,
    "eta":0.1,
    'colsample_bytree': 0.7,}

# Tran and test the model
xgrobs, xgreds, xgboost_model_ = xgboost_model(X_train_processed, X_test_processed, y_train_encoded, task_type='classification', **xgb_params)
accuracy_score(y_test_encoded, xgreds)
# Out:
# 0.7939367628970407

# %% [markdown]
# ### Random Forest

# %%
# RANDOM FOREST MODELS
# Declare parameters for 3 different Random Forest models, with different hyperparameters
random_forest1_param = {
    'max_depth': 20, 
    "n_estimators": 200,
    "criterion": "entropy",
}

random_forest2_param = {
    'max_depth': 20, 
    "n_estimators": 100,
    "criterion": "gini",
    "min_samples_split":200,
    "class_weight": "balanced",
    "max_features": 0.8,
}

random_forest3_param = {
    'max_depth': 10, 
    "n_estimators": 100,
    "criterion": "log_loss",
    "class_weight": "balanced",
}

# Create and train models
probs_rf1, preds_rf1, rf_model1 = random_forest(X_train_processed, X_test_processed, y_train_encoded, params=random_forest1_param)
probs_rf2, preds_rf2, rf_model2 = random_forest(X_train_processed, X_test_processed, y_train_encoded, params=random_forest2_param)
probs_rf3, preds_rf3, rf_model3 = random_forest(X_train_processed, X_test_processed, y_train_encoded, params=random_forest3_param)
# Get accuracy and compare against XGBoost
print("Accuracy XG Boost",accuracy_score(y_test_encoded, xgreds))
print("Accuracy Random Forest 1",accuracy_score(y_test_encoded, preds_rf1))
print("Accuracy Random Forest 2",accuracy_score(y_test_encoded, preds_rf2))
print("Accuracy Random Forest 3",accuracy_score(y_test_encoded, preds_rf3))
# Out:
# Accuracy XG Boost 0.7939367628970407
# Accuracy Random Forest 1 0.7763548223717531
# Accuracy Random Forest 2 0.7025902611967296
# Accuracy Random Forest 3 0.6794732653208885

# %% [markdown]
# ### K-Nearest Neighbor

# %%
# K-NEAREST NEIGHBORS MODELS (to diversify the stacked model)

# Create a KNN model
knn_model = KNeighborsClassifier(n_neighbors=8, weights="distance", metric="cityblock" )
# Train the model
knn_model.fit(X_train_processed, y_train_encoded)

# Predict to get accuracy
y_pred_knn = knn_model.predict(X_test_processed)
accuracy_knn = accuracy_score(y_test_encoded, y_pred_knn)
print(f"KNN model accuracy: {accuracy_knn}")


# Second KNN model with different parameters
knn_model_2 = KNeighborsClassifier(n_neighbors=5, metric="euclidean" )
# Train the model
knn_model_2.fit(X_train_processed, y_train_encoded)

# Predict to get accuracy
y_pred_knn = knn_model_2.predict(X_test_processed)
accuracy_knn_2 = accuracy_score(y_test_encoded, y_pred_knn)
print(f"KNN model accuracy 2: {accuracy_knn_2}")
# Out:
# KNN model accuracy: 0.7731350842920194
# KNN model accuracy 2: 0.7237898849576732

# %% [markdown]
# ### CatBoost

# %%
# CATEGORICAL BOOSTING MODEL

# Parameters for the CatBoost model
parameters = {"iterations": 300, 
              "learning_rate": 0.01, 
              "depth": 20, 
              "loss_function": "MultiClass",
              "verbose": 1,
              "eval_metric": "AUC",
              "early_stopping_rounds": 100}

# Create and train the CatBoost model
probs_catboost, preds_catboost, catboost_model_ = catboost_model(
    X_train_scaled,
    y_train,
    X_test=X_test_scaled
)
# Out:
# Learning rate set to 0.097861
# 0:	learn: 1.0355272	total: 276ms	remaining: 4m 36s
# 1:	learn: 0.9863355	total: 379ms	remaining: 3m 8s
# 2:	learn: 0.9458939	total: 484ms	remaining: 2m 40s
# 3:	learn: 0.9122525	total: 604ms	remaining: 2m 30s
# 4:	learn: 0.8851595	total: 717ms	remaining: 2m 22s
# 5:	learn: 0.8617496	total: 849ms	remaining: 2m 20s
# 6:	learn: 0.8413505	total: 970ms	remaining: 2m 17s
# 7:	learn: 0.8233633	total: 1.12s	remaining: 2m 18s
# 8:	learn: 0.8078007	total: 1.26s	remaining: 2m 19s
# 9:	learn: 0.7936216	total: 1.48s	remaining: 2m 26s
# 10:	learn: 0.7830095	total: 1.63s	remaining: 2m 26s
# 11:	learn: 0.7738389	total: 1.76s	remaining: 2m 24s
# 12:	learn: 0.7650120	total: 1.92s	remaining: 2m 25s
# 13:	learn: 0.7567353	total: 2.12s	remaining: 2m 28s
# 14:	learn: 0.7489574	total: 2.28s	remaining: 2m 29s
# 15:	learn: 0.7422734	total: 2.43s	remaining: 2m 29s
# 16:	learn: 0.7366766	total: 2.6s	remaining: 2m 30s
# 17:	learn: 0.7319031	total: 2.74s	remaining: 2m 29s
# ...

# %%
# Get the accuracy for the CatBoost model
accuracy_score(y_test, preds_catboost)
# Out:
# 0.7504883872368135

# %% [markdown]
# ## Meta Model

# %% [markdown]
# ### Stacking (Random Forest)

# %%
# All the models to be used in the stacking
# Final estimator will be a Random Forest with specific parameters
estimators = [
    ('rf1', rf_model1),
    ("rf2", rf_model2),
    ("rf3", rf_model3),
    ('xgb', xgboost_model_),
    ("knn1", knn_model),
    ("knn2", knn_model_2),
    ("catboost", catboost_model_)]

# Create the stacking model, Random Forest as final estimator and 5 folds for cross-validation
stacked_model = StackingClassifier(
    estimators=estimators,
    final_estimator=RandomForestClassifier(n_estimators=100, criterion="entropy", 
                                           max_depth=5 , random_state=42, min_samples_split=100),
    cv=5,
    n_jobs=-1)

# Train the model and predict the test set to get accuracy
stacked_model.fit(X_train_processed, y_train_encoded)
stacked_preds = stacked_model.predict(X_test_processed)

accuracy_score(y_test_encoded, stacked_preds)
# Out:
# 0.8030895014832501

# %% [markdown]
# ### Confussion Matrix

# %%
# Create the confusion matrix with ordered labels
ordered_labels = [0, 2, 1]
custom_names = ['Good', 'Standard', 'Poor']
cm = confusion_matrix(y_test_encoded, stacked_preds, labels=ordered_labels)
# Plot the confussion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=custom_names)
disp.plot(cmap='Greens')
plt.title('Confusion Matrix for Stacked Model')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Stacked Model')

# %%
# Calculate probabuilities for ROC curve
stacked_probs = stacked_model.predict_proba(X_test_processed)
# Get ROC metrics for the stacked model, for each class
metrics_roc_stacked = get_roc_metrics(y_test_encoded, stacked_probs, classes=[0, 1, 2])

# %%
# Save metrics for each class
stacked_fpr_good, stacked_tpr_good, stacked_auc_good, threshold_good = metrics_roc_stacked[0][1], metrics_roc_stacked[0][2], metrics_roc_stacked[0][3], metrics_roc_stacked[0][4]
stacked_fpr_standard, stacked_tpr_standard, stacked_auc_standard, threshold_standard = metrics_roc_stacked[1][1], metrics_roc_stacked[1][2], metrics_roc_stacked[1][3], metrics_roc_stacked[1][4]
stacked_fpr_poor, stacked_tpr_poor, stacked_auc_poor, threshold_poor = metrics_roc_stacked[2][1], metrics_roc_stacked[2][2], metrics_roc_stacked[2][3], metrics_roc_stacked[2][4]

# %%
# Curve for class Good
plt.plot(stacked_fpr_good, stacked_tpr_good, color = "lightblue" ,label=f'Stacked Model Good (AUC = {stacked_auc_good:.2f})')
# Curve for class Standard
plt.plot(stacked_fpr_standard, stacked_tpr_standard, color = "orange" ,label=f'Stacked Model Standard (AUC = {stacked_auc_standard:.2f})')
# Curve for class Poor
plt.plot(stacked_fpr_poor, stacked_tpr_poor, color = "green" ,label=f'Stacked Model Poor (AUC = {stacked_auc_poor:.2f})')
# Reference line
plt.plot([0, 1], [0, 1], 'k--')

# Format the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (Test Set)')
plt.legend(fontsize=8)
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ### Client Model

# %%
# See how it behaves for credit decission (GOODs and STANDARDs approve, POORs reject)

# Create a binary classification dataset using the stacked model and the test set
y_test_encoded_ = pd.Series(y_test_encoded.copy()).replace({0: 1, 1: 0, 2: 1}).values
stacked_preds_ = pd.Series(stacked_preds).replace({0: 1, 1: 0, 2: 1}).values

# Calculate accuracy for the stacked model
stacked_preds_accuracy_ = accuracy_score(y_test_encoded_, stacked_preds_)
print(f"Stacked Credit Decision Model Accuracy: {stacked_preds_accuracy_*100:.2f}%")
# Out:
# Precisión Modelo Stacked de la Decisión Crediticia: 88.75%

# %%
file = "" #Insert Path Here
pred = get_predictions(file)
print(pred)
